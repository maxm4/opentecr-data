# %%
# %run reference_mapping.py

# define paths and conditions
mappings_url = "https://raw.githubusercontent.com/roberts-farm-of-ideas/8/56bab7c99ef340a6c3853b595f4d777ac7288c54/materials/reference_code_mappings/reference_code_mappings.csv"
reference_ids_column = 'reference_code_in_online_database'
doi_column = 'doi_from_Robert'
pmid_column = 'pmid'
zip_path = 'TECRDB.zip'

mapping = mapRef(mappings_url, zip_path)
mapping.apply(reference_ids_column, doi_column, pmid_column)
# Out:
# Collected 541 PubMed IDs
# References added to 1637 datums
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\zipfile.py:1514: UserWarning: Duplicate name: 'mapped_TECRDB_scrape.csv'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\zipfile.py:1514: UserWarning: Duplicate name: 'references_with_abstracts.csv'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
#                        Enzyme:  \
# 0      aspartate ammonia-lyase
# 1      aspartate ammonia-lyase
# 2           fumarate hydratase
# 3           fumarate hydratase
# 4           fumarate hydratase
# ...                        ...
# 4036    triacylglycerol lipase
# 4037    triacylglycerol lipase
# 4038    triacylglycerol lipase
# 4039    triacylglycerol lipase
# 4040    triacylglycerol lipase
#
#                                               Reaction:  \
# ...

# %%
print(len(mapping.tecrdb.loc[mapping.tecrdb['PMID'] != ' ']))
print(len(mapping.tecrdb.loc[mapping.tecrdb['DOI'] != ' ']))
# Out:
# 1637
# 1637
